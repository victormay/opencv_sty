# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
def cv2show(img,T=1000,D=True,name=""):
    cv2.namedWindow(name,cv2.WINDOW_NORMAL)
    cv2.imshow(name,img)
    cv2.waitKey(T)
    if D:
        cv2.destroyAllWindows()
        

def matshow(img_ls,R=1,C=1):
    for i in range(R*C):
#         {None, 'aitoff', 'hammer', 'lambert', 'mollweide', 'polar', 'rectilinear', str}
        plt.subplot(R,C,i+1)
        plt.imshow(img_ls[i])
        plt.title(f"{i}")
        plt.xticks([])
        plt.yticks([])
    
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0, hspace=0)
    plt.show()

# %%
bgr_img = cv2.imread("test1.jpg",1)
rgb_img = cv2.cvtColor(bgr_img,cv2.COLOR_BGR2RGB)
hsv_img = cv2.cvtColor(bgr_img,cv2.COLOR_BGR2HSV)
matshow([bgr_img,rgb_img,hsv_img],1,3)

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    exit()

while True:
    ret,frame = cap.read()
    if not ret:
        cv2.destroyAllWindows()
    frame = np.fliplr(frame)
    cv2.namedWindow("video",cv2.WINDOW_NORMAL)
    cv2.imshow("video",frame1)
    if cv2.waitKey(10) in [ord("q"),ord("Q")]:
        cv2.destroyAllWindows()
        break

cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13504/3841583280.py in <module>
#       9     frame = np.fliplr(frame)
#      10     cv2.namedWindow("video",cv2.WINDOW_NORMAL)
# ---> 11     cv2.imshow("video",frame1)
#      12     if cv2.waitKey(10) in [ord("q"),ord("Q")]:
#      13         cv2.destroyAllWindows()
#
# NameError: name 'frame1' is not defined
